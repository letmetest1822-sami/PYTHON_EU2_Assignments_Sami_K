# %%
""" Question01_LeasingOffice

* In this assignment, you will write a program for the Leasing office.

Declare and assign value for numberOfBedrooms variable
Declare startingPrice variable and set the price to 0.

Using Multi-Way If statement, create this program logic:

numberOfBedrooms is 1
print "One Bedroom Selected"
set startingPrice as 1100

numberOfBedrooms is 2
print "Two Bedroom Selected"
set startingPrice as 1850

numberOfBedrooms is 3
print "Three Bedroom Selected"
set startingPrice as 2550

All other inputs:
print "No such Bedrooms available"

Print "Starting Price: value"


"""
numberOfBedrooms = 3

if numberOfBedrooms == 1:
    print("One Bedroom Selected.")
    startingPrice = 1100
    print("Starting Price is : {} ".format(startingPrice))

elif numberOfBedrooms == 2:
    print("Two Bedrooms Selected." )
    startingPrice = 1850
    print("Starting Price is : {} ".format (startingPrice))

elif numberOfBedrooms == 3:
    print("Three Bedrooms Selected.")
    startingPrice = 2550;
    print("Starting Price is : {} ".format(startingPrice));

else:
    print("No such Bedrooms available...")
# Out:
# Three Bedrooms Selected.
# Starting Price is : 2550

# %%
""" Question02_num1_vs_num2

Declare and assign value for num1 and num2 variables

Using Multi-Branch if statements, check if num1 and num2 are equal, or not. 
Please follow the below examples and print message accordingly:


num1 = 10
num2 = 10
10 and 10 are equal


num1 = 100
num2 = 55
100 is greater than 55


num1 = 33
num2 = 333
333 is greater than 33 

"""
num1 = 33
num2 = 333

if num1 == num2:
    print("{} and {} are equal.".format(num1, num2 ))
    
elif num1 > num2:
    print("{} is greater than {}.".format(num1, num2 ))

elif num2 > num1:
    print("{} is greater than {}.".format(num2, num1 ))
# Out:
# 333 is greater than 33.

# %%
"""Question03_positiveOrNegative

* Declare and assign value for a number variable
* Using Multi-Branch if statements, check if the number is positive, negative or zero. 
* Please follow the below examples and print message accordingly:

    number = -10
        10 is positive

    number = -55
        -55 is negative

    number = 0
        it is zero

"""

number = -10;

if number > 0:
    print( "{} is positive.".format(number))

elif number < 0:
    print( "{} is negative.".format(number))

elif number == 0:
    print( "{}  is zero.".format(number))
# Out:
# -10 is negative.

# %%
""" Question04_EvenOdd

* Declare and assign value for a number variable
* Using conditional statements, check if the number is odd or even. 
* Please follow the below examples and print message accordingly:

	number = 10
	10 is even

	number = 33
	33 is odd

"""

number = 11;

if number == 0:
    print( "{} is zero.".format(number))
    
elif number%2 == 0: 
    print("{} is even".format(number))

elif number%2 == 1: 
    print("{} is odd".format(number))
# Out:
# 11 is odd

# %%
""" Question05_HappyValleySchool

In the Happy Valley School System, children are classified by age as follows:

    less than 2,   ineligible
              2,   toddler
            3-5,   early childhood
            6-7,   young reader
           8-10,   elementary
      11 and 12,   middle
             13,   impossible
          14-16,   high school
          17-18,   scholar
greater than 18,   ineligible

* Given an int variable age, write an if statement that prints out, 
on a line by itself, the appropriate label from the above list based on age.

Sample Output

Age : 8
Elementary

"""

age = int (input("Please insert your age : "))

#age = 1

if age>18:
    print("Age  : {} \nIneligible". format(age))

elif age == 17 or age == 18:
    print("Age  : {} \nScholar". format(age))
          
elif age >= 14 and age <= 16:
    print("Age  : {} \nHigh School". format(age))
          
elif age == 13:
    print("Age  : {} \nImpossible". format(age))          
          
elif age == 11 or age == 12:
    print("Age  : {} \nMiddle". format(age))

elif age >= 8 and age <= 10:
    print("Age  : {} \nElementary". format(age))  
      
elif age == 6 or age == 7:
    print("Age  : {} \nYoung Reader". format(age))   
      

elif age >= 3 and age < 6:
    print("Age  : {} \nEarly Childhood". format(age))

elif age == 2:
    print("Age  : {} \nToddler". format(age))

elif age <2:
    print("Age  : {} \nIneligible". format(age))
# Out:
# Please insert your age : 11
# Age  : 11
# Middle

# %%
""" Question06_SDET_Motors

* SDET Motors Inc. is recalling all vehicles from model years 
* 1995-1998, 2001-2002, 2004-2006 and 2015-2017.
* In this assignment, you will write a program that will find a vehicle for recall.
* -Declare and assign a value for variable vehicleYear
* if the value of modelYear does fall within the four recall ranges, display output:
* "Your vehicle needs to be recalled!"
*  Otherwise, display the message:
* "Your vehicle is fine, enjoy!" 

"""
#year = 1997;

year = int(input("Please enter the model year of your car: "))

if (1995 <= year <= 1998) or (2001 <= year<=2002) or (2004 <= year <= 2006) or (2015 <= year <= 2017):
    print("Your vehicle needs to be recalled!")
    
else:
    print("Your vehicle is fine, enjoy!")
# Out:
# Please enter the model year of your car: 199
# Your vehicle is fine, enjoy!

# %%
""" Question07_mediumNumber

* Write a program that will return mid number out of three numbers. 
* No need to do any calculations.
* Declare and assign 3 int variables: num1, num2, num3.

    Example 1:
        num1 = 14
        num2 = 52
        num3 = 25
            Medium value is: 25
            
    Example 2:
        num1 = 140
        num2 = 34
        num3 = 1
            Medium value is: 34
"""

num1 = 180
num2 = 500
num3 = 90

if (num1 > num2) and (num1 > num3):
    if (num2 > num3):
        print("Medium value is : {} ".format(num2))
    else :
        print("Medium value is : {} ".format(num3))
        
elif (num2 > num1) and(num2 > num3):
    if (num1 > num3):
        print("Medium value is : {} ".format(num1))
    else :
        print("Medium value is : {} ".format(num3))

elif (num3 > num1) and (num3 > num2):
    if (num2 > num1):
        print("Medium value is : {} ".format(num2))
    else :
        print("Medium value is : {} ".format(num1))
# Out:
# Medium value is : 180

# %%
""" Question08_Blackjack

* in blackjack after the player asks to keep the house 4 things may happen.
* player and house scores are represented by player and house int variables.
 * check them using ifs to determine the result.

        for example:
            player = 21
            house  =  8
                output: bust

            player =  7
            house  = 10
                output: player loss

            player = 4
            house  = 4
                output: its a tie

            player = 12
            house  =  7
                output: player wins
"""
house = 2
player = 2

CardTotal = house + player

if CardTotal>21:
    print("bust")
#1)if the card total is bigger then 21 the player busts.

elif house > player:
    print("player loss")
#2)if the house score is bigger then the player, the player loses.
        
elif player == house:
    print("its a tie")
#3)if the player score is equal to the house then they are a draw.
        
elif player > house:
    print("player wins")
#4)if the player score is bigger then the house the player wins.
# Out:
# its a tie

# %%
""" Question09_slice_integer

In this task, you need to slice an integer and print numbers one by one from the new line.
        Example # 1
            Your number: 12345
                -Display prompt: 1
                -Display prompt: 2
                -Display prompt: 3
                -Display prompt: 4
                -Display prompt: 5
"""
Number = int(input("Please enter a number to slice : "))
copy1Number = Number
copy2Number = Number

i = 0

while copy1Number != 0:
    copy1Number=copy1Number//10
    i += 1
    
for each in range(1,i+1):
    displayNumber = copy2Number//(10**(i-1))
    copy2Number = copy2Number - (displayNumber*(10**(i-1)))
    
    print("Display prompt {}".format(displayNumber))
    i -= 1
# Out:
# Please enter a number to slice : 4563
# Display prompt 4
# Display prompt 5
# Display prompt 6
# Display prompt 3

# %%
""" Question10_HTTP_ErrorCodes

* HTTP is the protocol that governs communications between web servers and web clients 
* (i.e. browsers). Part of the protocol includes a status code returned by the server 
* to tell the browser the status of its most recent page request. 
* Some of the codes and their meanings are listed below:

HTTP STATUS CODE

CODE	DESCRIPTION			CODE	DESCRIPTION
200		OK					400		Bad Request
201		Created				401		Unauthorized
202		Accepted			403		Forbidden
301		Moved Permanently	404		Not found
303		See other			410		Gone
304		Not modified		500		Internal Server Error
307		Temporary Redirect	503		Service Unavailable
 
* Given an int variable status, write a switch statement that prints out, on a line by itself, 
* the appropriate label from the above list based on status. 
* Otherwise, print warning message: "Invalid status code!".

        Example:
            Display message	: "Enter status code:"
            input			:  200
            Display message	: "OK" 


"""
code = input("Enter status code: ")

if code == "200":
    print("OK")
    
elif code == "201":
  	print("Created")
    
elif code == "202":
  	print("Accepted")
    
elif code == "301":
  	print("Moved Permanently")
    
elif code == "303":
  	print("See other")
    
elif code == "304":
  	print("Not modified")
    
elif code == "307":
  	print("Temporary Redirect")
    
elif code == "400":
  	print("Bad Request")
    
elif code == "401":
  	print("Unauthorized")
    
elif code == "403":
  	print("Forbidden")
    
elif code == "404":
  	print("Not found")
    
elif code == "410":
  	print("Gone")
    
elif code == "500":
  	print("Internal Server Error")
    
elif code == "503":
  	print("Service Unavailable")
    
else:
  	print("Invalid status code!")
# Out:
# Enter status code: 402
# Invalid status code!
